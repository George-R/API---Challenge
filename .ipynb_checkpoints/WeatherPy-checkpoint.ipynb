# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.
#
# #Analysis
#
# Trend 1
#
#     The closer you are to the equater, the hotter it gets.
#
# Trend 2
#
#     Coordinates don't seem to determine much in terms of humdidity  or windspeed.
#
# Trend 3
#
#     Windspeeds are fairly stable throughout the wortld, with very few outliers.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

api_key
# Out:
# '193421888ad09cbf01d51768678c4ba6'

# %% [markdown]
# ## Generate Cities List

# %%
# empty lists for location and cities
lat_long = []
cities = []

# Create a set of random lat and lng combinations
lat = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lng = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_long = zip(lat, lng)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_long:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)

cities
# Out:
# ['rikitea',
#  'beringovskiy',
#  'vaini',
#  'qaanaaq',
#  'svetlaya',
#  'nivala',
#  'kandalaksha',
#  'bolonchen',
#  'tiksi',
#  'wakkanai',
#  'deputatskiy',
#  'havelock',
#  'cape town',
#  'constitucion',
#  'isangel',
#  'saint-philippe',
#  'darhan',
#  'laguna',
#  'taolanaro',
#  'khromtau',
#  'tabuk',
#  'shelburne',
#  'georgetown',
#  'maputo',
#  'florianopolis',
#  'hilo',
#  'albany',
#  'bredasdorp',
#  'mataura',
#  'bambous virieux',
#  'huejuquilla el alto',
#  'grand gaube',
#  'punta arenas',
#  'balkhash',
#  'ushuaia',
#  'kapaa',
#  'bluff',
#  'norman wells',
#  'hermanus',
#  'east london',
#  'lulea',
#  'belushya guba',
#  'codrington',
#  'mount gambier',
#  'naze',
#  'nikolskoye',
#  'warqla',
#  'dakar',
#  'torbay',
#  'verkhnyaya inta',
#  'tecoanapa',
#  'bengkulu',
#  'sentyabrskiy',
#  'sitka',
#  'klaksvik',
#  'tiznit',
#  'pisco',
#  'upernavik',
#  'umm kaddadah',
#  'orebro',
#  'husavik',
#  'hamilton',
#  'hasaki',
#  'port shepstone',
#  'mar del plata',
#  'cherskiy',
#  'mys shmidta',
#  'port elizabeth',
#  'tuktoyaktuk',
#  'lebu',
#  'puerto ayora',
#  'vila velha',
#  'thompson',
#  'rassvet',
#  'talnakh',
#  'kailua',
#  'pierre',
#  'barrow',
#  'pangnirtung',
#  'jamestown',
#  'yar-sale',
#  'ziway',
#  'papara',
#  'hobart',
#  'ugoofaaru',
#  'ambilobe',
#  'nouadhibou',
#  'lazarev',
#  'chokurdakh',
#  'praia da vitoria',
#  'komsomolskiy',
#  'keshan',
#  'brandon',
#  'zhaoyuan',
#  'busselton',
#  'kamenka',
#  'illoqqortoormiut',
#  'tasiilaq',
#  'palabuhanratu',
#  'nyakabindi',
#  'san patricio',
#  'aklavik',
#  'porto seguro',
#  'hyeres',
#  'camopi',
#  'linjiang',
#  'stavern',
#  'vila franca do campo',
#  'caceres',
#  'esperance',
#  'butaritari',
#  'kizilskoye',
#  'khatanga',
#  'ukiah',
#  'coihaique',
#  'comodoro rivadavia',
#  'barentsburg',
#  'khonuu',
#  'victoria',
#  'anchorage',
#  'bustamante',
#  'avarua',
#  'igarka',
#  'sakaiminato',
#  'port alfred',
#  'borlange',
#  'blythe',
#  'arraial do cabo',
#  'chuy',
#  'katsuura',
#  'turayf',
#  'anadyr',
#  'hithadhoo',
#  'cockburn town',
#  'manono',
#  'moron',
#  'sola',
#  'tuatapere',
#  'alofi',
#  'nanortalik',
#  'vaitupu',
#  'sao domingos do maranhao',
#  'narsaq',
#  'shubarkuduk',
#  'la fria',
#  'saskylakh',
#  'severo-kurilsk',
#  'solnechnyy',
#  'kununurra',
#  'melo',
#  'jining',
#  'karratha',
#  'iwaki',
#  'kavieng',
#  'yulara',
#  'artyk',
#  'portland',
#  'amderma',
#  'wiang sa',
#  'nieuwpoort',
#  'andarab',
#  'ararat',
#  'maniitsoq',
#  'leo',
#  'fare',
#  'ust-kuyga',
#  'castro',
#  'sur',
#  'ponta do sol',
#  'atuona',
#  'jujuy',
#  'tessalit',
#  'bambanglipuro',
#  'puerto leguizamo',
#  'college',
#  'baruun-urt',
#  'alice springs',
#  'ariquemes',
#  'eydhafushi',
#  'lugovoy',
#  'te anau',
#  'bar harbor',
#  'carnarvon',
#  'bonthe',
#  'altay',
#  'roura',
#  'avera',
#  'airai',
#  'christchurch',
#  'kazalinsk',
#  'tuysarkan',
#  'kulhudhuffushi',
#  'ilhabela',
#  'keetmanshoop',
#  'rio verde de mato grosso',
#  'caravelas',
#  'xining',
#  'bathsheba',
#  'sorvag',
#  'mackay',
#  'candolim',
#  'new norfolk',
#  'kerteh',
#  'necochea',
#  'yatou',
#  'kholtoson',
#  'vestmanna',
#  'boyolangu',
#  'chara',
#  'abu samrah',
#  'samusu',
#  'alyangula',
#  'kosh-agach',
#  'northam',
#  'palmer',
#  'taltal',
#  'evensk',
#  'cedral',
#  'butajira',
#  'asau',
#  'vestmannaeyjar',
#  'shiyan',
#  'bethel',
#  'faanui',
#  'gao',
#  'suntar',
#  'sarangani',
#  'cabo san lucas',
#  'never',
#  'ribeira grande',
#  'namibe',
#  'dutlwe',
#  'hualmay',
#  'sorland',
#  'sao filipe',
#  'honningsvag',
#  'beloha',
#  'nizwa',
#  'agadir',
#  'ozgon',
#  'dibaya',
#  'jharsuguda',
#  'ngunguru',
#  'suffolk',
#  'sambava',
#  'rawson',
#  'poya',
#  'reporoa',
#  'yellowknife',
#  'cidreira',
#  'bosaso',
#  'arman',
#  'calabozo',
#  'mingyue',
#  'grand centre',
#  'ancud',
#  'iranshahr',
#  'dikson',
#  'touros',
#  'cayenne',
#  'riachao das neves',
#  'takaka',
#  'nisia floresta',
#  'tilichiki',
#  'quesnel',
#  'sompeta',
#  'amazar',
#  'burnie',
#  'cabedelo',
#  'barra do garcas',
#  'westport',
#  'clarence town',
#  'bouza',
#  'reconquista',
#  'peniche',
#  'half moon bay',
#  'micheweni',
#  'mancio lima',
#  'eldikan',
#  'lucea',
#  'lasa',
#  'bilma',
#  'matara',
#  'champaign',
#  'riberalta',
#  'rincon',
#  'jati',
#  'vao',
#  'pasighat',
#  'ciudad del maiz',
#  'san policarpo',
#  'thinadhoo',
#  'port hardy',
#  'fortuna',
#  'okhotsk',
#  'marang',
#  'ilulissat',
#  'provideniya',
#  'san cristobal',
#  'tatawin',
#  'muros',
#  'batemans bay',
#  'alta floresta',
#  'viedma',
#  'pecos',
#  'zhigansk',
#  'boa esperanca',
#  'moose factory',
#  'mount isa',
#  'tateyama',
#  'ust-bolsheretsk',
#  'ixtapa',
#  'adrar',
#  'uchiza',
#  'brookhaven',
#  'nome',
#  'eberswalde',
#  'sheridan',
#  'rio gallegos',
#  'iqaluit',
#  'rocha',
#  'kingsville',
#  'tabou',
#  'bereda',
#  'palora',
#  'kupang',
#  'tocopilla',
#  'lindas',
#  'san fernando',
#  'buala',
#  'tabiauea',
#  'beyneu',
#  'ahipara',
#  'puksoozero',
#  'zhangye',
#  'birjand',
#  'costinesti',
#  'saint-michel-des-saints',
#  'ksenyevka',
#  'kovur',
#  'pevek',
#  'wolbrom',
#  'bolshaya chernigovka',
#  'mareeba',
#  'louisbourg',
#  'marienburg',
#  'balikpapan',
#  'lavrentiya',
#  'sao joao da barra',
#  'huancabamba',
#  'souillac',
#  'kudahuvadhoo',
#  'kahului',
#  'beinamar',
#  'narsipatnam',
#  'chapais',
#  'shimanovsk',
#  'thames',
#  'awash',
#  'macaboboni',
#  'rena',
#  'saint-joseph',
#  'teya',
#  'aitape',
#  'tahe',
#  'bitung',
#  'kodiak',
#  'pelham',
#  'hay river',
#  'serdobsk',
#  'sterling',
#  'pacific grove',
#  'port-cartier',
#  'malwan',
#  'cuamba',
#  'disna',
#  'luang prabang',
#  'inuvik',
#  'junction city',
#  'olhao',
#  'madimba',
#  'omsukchan',
#  'panshi',
#  'santo andre',
#  'salalah',
#  'villa oliva',
#  'kenora',
#  'saint anthony',
#  'livingstonia',
#  'grand river south east',
#  'tsihombe',
#  'mahebourg',
#  'formosa',
#  'bossembele',
#  'taoudenni',
#  'gat',
#  'baykit',
#  'helong',
#  'lompoc',
#  'raga',
#  'mergui',
#  'tuban',
#  'angoram',
#  'acapulco',
#  'makubetsu',
#  'mahibadhoo',
#  'orotukan',
#  'coahuayana',
#  'bargal',
#  'ureki',
#  'namatanai',
#  'lodwar',
#  'baghdad',
#  'vila',
#  'sioux lookout',
#  'kaeo',
#  'mnogovershinnyy',
#  'lakselv',
#  'iskateley',
#  'soubre',
#  'greensburg',
#  'bandarbeyla',
#  'bogande',
#  'geraldton',
#  'rafai',
#  'bolungarvik',
#  'nemuro',
#  'agapovka',
#  'zhongshu',
#  'usinsk',
#  'arlit',
#  'nizhneyansk',
#  'lata',
#  'ust-barguzin',
#  'donskoy',
#  'nishihara',
#  'jiddah',
#  'sainte-anne-des-monts',
#  'sabha',
#  'hokitika',
#  'cesenatico',
#  'bay roberts',
#  'kachug',
#  'saint george',
#  'taksimo',
#  'gomel',
#  'wanparti',
#  'porto recanati',
#  'dingle',
#  'kodinsk',
#  'neiafu',
#  'poum',
#  'hobyo',
#  'santa cruz',
#  'waingapu',
#  'taft',
#  'blind river',
#  'saldanha',
#  'lisburn',
#  'ahmadnagar',
#  'luderitz',
#  'mentok',
#  'xichang',
#  'nuevo celilac',
#  'flinders',
#  'sao borja',
#  'cazaje',
#  'leningradskiy',
#  'oistins',
#  'prokopyevsk',
#  'la ronge',
#  'batticaloa',
#  'olafsvik',
#  'campina grande do sul',
#  'mehran',
#  'majene',
#  'jalu',
#  'imuris',
#  'makakilo city',
#  'cumpas',
#  'innisfail',
#  'nchelenge',
#  'laje',
#  'vanavara',
#  'kruisfontein',
#  'antropovo',
#  'katangli',
#  'goudomp',
#  'padre bernardo',
#  'porto torres',
#  'labutta',
#  'aswan',
#  'karauzyak',
#  'san vicente',
#  'shitkino',
#  'nikolsk',
#  'falmouth',
#  'pokhara',
#  'cap-aux-meules',
#  'tura',
#  'sosnovoborsk',
#  'mukhen',
#  'acarau',
#  'honiara',
#  'norway',
#  'griffith',
#  'astana',
#  'chalmette',
#  'korbach',
#  'lachi',
#  'donskoye',
#  'sanmenxia',
#  'petropavlovsk-kamchatskiy',
#  'port hawkesbury',
#  'gubkinskiy',
#  'redlands',
#  'nylstroom',
#  'los llanos de aridane',
#  'tarauaca',
#  'argostolion',
#  'aguimes',
#  'masvingo',
#  'aflu',
#  'trelew',
#  'port lincoln',
#  'havre-saint-pierre',
#  'korla',
#  'pinczow',
#  'eyl',
#  'channel-port aux basques',
#  'plettenberg bay',
#  'winterberg',
#  'raiganj',
#  'dabhol',
#  'bilibino',
#  'xiangxiang',
#  'anloga',
#  'amahai',
#  'mogeiro',
#  'kokopo',
#  'odweyne',
#  'aripuana',
#  'chingirlau',
#  'mingguang',
#  'penapolis',
#  'ruatoria',
#  'mastung',
#  'verkhnevilyuysk',
#  'ronne',
#  'longview',
#  'mezen',
#  'marieville',
#  'antofagasta',
#  'joshimath',
#  'wolmaranstad',
#  'whitehorse',
#  'nhulunbuy',
#  'tangzhai',
#  'sinnamary',
#  'tucuman',
#  'el naranjo',
#  'pingliang',
#  'dinghai',
#  'guerrero negro',
#  'pereslavl-zalesskiy',
#  'itarema',
#  'toora-khem',
#  'oyonnax',
#  'kisangani',
#  'burica',
#  'russellville',
#  'den helder',
#  'daru',
#  'goderich',
#  'fort saint james',
#  'bischofswerda',
#  'shibetsu',
#  'umm lajj',
#  'hohhot',
#  'vyazemskiy',
#  'ivanovskoye',
#  'were ilu',
#  'lhuntshi',
#  'yellandu',
#  'poso',
#  'rungata',
#  'vostok',
#  'sao desiderio',
#  'ramos arizpe',
#  'umzimvubu',
#  'dobarceni',
#  'antonina',
#  'alappuzha',
#  'saint-francois',
#  'nikki',
#  'verkh-usugli',
#  'bur gabo',
#  'brae',
#  'luwuk',
#  'lolua',
#  'tumannyy',
#  'bulgan',
#  'pemangkat',
#  'liberty',
#  'clyde river',
#  'waipawa',
#  'tibati',
#  'tongzi',
#  'maningrida',
#  'qasigiannguit']

# %%
city_test = ['Ajax', 'Kiev', 'Kingsotn', 'Cluj-Napoca', 'Denver', 'Berlin', 'Beijing', 'Geneva', 'San Francisco', 
             'Jamaica','Jen','Beyonce', 'George', 'London']

#URL for API extraction
base_url = f"http://api.openweathermap.org/data/2.5/weather?&appid={api_key}&q="

#Empty list and value for city
c_test = []
c_number=1

#Print log 
for i in city_test:
    c_url = base_url + i
    response_t= requests.get(c_url).json()

    try:
        c_test.append(response_t['name'])
        print(f"Record {c_number} of|{i}")
        c_number +=1
        
    except:
        print(f"Not found.  Next!")
        pass
# Out:
# Record 1 of|Ajax
# Record 2 of|Kiev
# Not found.  Next!
# Record 3 of|Cluj-Napoca
# Record 4 of|Denver
# Record 5 of|Berlin
# Record 6 of|Beijing
# Record 7 of|Geneva
# Record 8 of|San Francisco
# Record 9 of|Jamaica
# Record 10 of|Jen
# Not found.  Next!
# Record 11 of|George
# Record 12 of|London

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#API Calls
#Perform a weather check on each city using a series of successive API calls.
#Perform a quick test by coming up with a list of cities with successive API calls.  
# Create empty lists for dataframe to plot data

city = []
temp_max = []
cloud = []
humid = []
wind = []
lat = []
long = []
date= []
country = []

print("Retreive Data")
print("..............................")

# Value for record and count
record = 1
set_number = 1

# Loop through the cities in the full cities list 
# Also, to get a print log of all the cities found 



for city in cities:
    weather_url = base_url + city
    response= requests.get(weather_url + "&units=metric").json()

    try:
        cloud.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        humid.append(response['main']['humidity'])
        lat.append(response['coord']['lat'])
        long.append(response['coord']['lon'])
        temp_max.append(response['main']['temp_max'])
        wind.append(response['wind']['speed'])
        print(f"Getting city {record} of set {set_number}|{city}")
        
        # record and set count
        if record > 49:
            record = 1
            set_number += 1
            cityname.append(city)
        else:
            record += 1
            cityname.append(city)
    except:
        # Append null values
        print(f"Not found. Next....")
        pass
print("-----------------------------")
print("Complete!") 
print("-----------------------------")
# Out:
# Retreive Data
# ..............................
# Getting city 1 of set 1|rikitea
# Not found. Next....
# Getting city 2 of set 1|beringovskiy
# Not found. Next....
# Getting city 3 of set 1|vaini
# Not found. Next....
# Getting city 4 of set 1|qaanaaq
# Not found. Next....
# Getting city 5 of set 1|svetlaya
# Not found. Next....
# Getting city 6 of set 1|nivala
# Not found. Next....
# Getting city 7 of set 1|kandalaksha
# Not found. Next....
# Not found. Next....
# Getting city 8 of set 1|tiksi
# Not found. Next....
# Getting city 9 of set 1|wakkanai
# Not found. Next....
# Getting city 10 of set 1|deputatskiy
# Not found. Next....
# Getting city 11 of set 1|havelock
# Not found. Next....
# Getting city 12 of set 1|cape town
# Not found. Next....
# Getting city 13 of set 1|constitucion
# Not found. Next....
# Getting city 14 of set 1|isangel
# Not found. Next....
# Getting city 15 of set 1|saint-philippe
# Not found. Next....
# Getting city 16 of set 1|darhan
# Not found. Next....
# Getting city 17 of set 1|laguna
# Not found. Next....
# Not found. Next....
# Getting city 18 of set 1|khromtau
# Not found. Next....
# Getting city 19 of set 1|tabuk
# Not found. Next....
# Getting city 20 of set 1|shelburne
# Not found. Next....
# Getting city 21 of set 1|georgetown
# Not found. Next....
# Getting city 22 of set 1|maputo
# Not found. Next....
# Getting city 23 of set 1|florianopolis
# Not found. Next....
# Getting city 24 of set 1|hilo
# Not found. Next....
# Getting city 25 of set 1|albany
# Not found. Next....
# Getting city 26 of set 1|bredasdorp
# Not found. Next....
# Getting city 27 of set 1|mataura
# Not found. Next....
# Getting city 28 of set 1|bambous virieux
# Not found. Next....
# Getting city 29 of set 1|huejuquilla el alto
# Not found. Next....
# Getting city 30 of set 1|grand gaube
# Not found. Next....
# Getting city 31 of set 1|punta arenas
# Not found. Next....
# Getting city 32 of set 1|balkhash
# Not found. Next....
# Getting city 33 of set 1|ushuaia
# Not found. Next....
# Getting city 34 of set 1|kapaa
# Not found. Next....
# Getting city 35 of set 1|bluff
# Not found. Next....
# Getting city 36 of set 1|norman wells
# Not found. Next....
# Getting city 37 of set 1|hermanus
# Not found. Next....
# Getting city 38 of set 1|east london
# Not found. Next....
# Getting city 39 of set 1|lulea
# Not found. Next....
# Not found. Next....
# Getting city 40 of set 1|codrington
# Not found. Next....
# Getting city 41 of set 1|mount gambier
# Not found. Next....
# Getting city 42 of set 1|naze
# Not found. Next....
# Getting city 43 of set 1|nikolskoye
# Not found. Next....
# Not found. Next....
# Getting city 44 of set 1|dakar
# Not found. Next....
# Getting city 45 of set 1|torbay
# Not found. Next....
# Getting city 46 of set 1|verkhnyaya inta
# Not found. Next....
# Getting city 47 of set 1|tecoanapa
# Not found. Next....
# Getting city 48 of set 1|bengkulu
# Not found. Next....
# Not found. Next....
# Getting city 49 of set 1|sitka
# Not found. Next....
# Getting city 50 of set 1|klaksvik
# Not found. Next....
# Getting city 1 of set 2|tiznit
# Not found. Next....
# Getting city 2 of set 2|pisco
# Not found. Next....
# Getting city 3 of set 2|upernavik
# Not found. Next....
# Getting city 4 of set 2|umm kaddadah
# Not found. Next....
# Getting city 5 of set 2|orebro
# Not found. Next....
# Getting city 6 of set 2|husavik
# Not found. Next....
# Getting city 7 of set 2|hamilton
# Not found. Next....
# Getting city 8 of set 2|hasaki
# Not found. Next....
# Getting city 9 of set 2|port shepstone
# Not found. Next....
# Getting city 10 of set 2|mar del plata
# Not found. Next....
# Getting city 11 of set 2|cherskiy
# Not found. Next....
# Not found. Next....
# Getting city 12 of set 2|port elizabeth
# Not found. Next....
# Getting city 13 of set 2|tuktoyaktuk
# Not found. Next....
# Getting city 14 of set 2|lebu
# Not found. Next....
# Getting city 15 of set 2|puerto ayora
# Not found. Next....
# Getting city 16 of set 2|vila velha
# Not found. Next....
# Getting city 17 of set 2|thompson
# Not found. Next....
# Getting city 18 of set 2|rassvet
# Not found. Next....
# Getting city 19 of set 2|talnakh
# Not found. Next....
# Getting city 20 of set 2|kailua
# Not found. Next....
# Getting city 21 of set 2|pierre
# Not found. Next....
# Getting city 22 of set 2|barrow
# Not found. Next....
# Getting city 23 of set 2|pangnirtung
# Not found. Next....
# Getting city 24 of set 2|jamestown
# Not found. Next....
# Getting city 25 of set 2|yar-sale
# Not found. Next....
# Getting city 26 of set 2|ziway
# Not found. Next....
# Getting city 27 of set 2|papara
# Not found. Next....
# Getting city 28 of set 2|hobart
# Not found. Next....
# Getting city 29 of set 2|ugoofaaru
# Not found. Next....
# Getting city 30 of set 2|ambilobe
# Not found. Next....
# Getting city 31 of set 2|nouadhibou
# Not found. Next....
# Getting city 32 of set 2|lazarev
# Not found. Next....
# Getting city 33 of set 2|chokurdakh
# Not found. Next....
# Getting city 34 of set 2|praia da vitoria
# Not found. Next....
# Getting city 35 of set 2|komsomolskiy
# Not found. Next....
# Not found. Next....
# Getting city 36 of set 2|brandon
# Not found. Next....
# Getting city 37 of set 2|zhaoyuan
# Not found. Next....
# Getting city 38 of set 2|busselton
# Not found. Next....
# Getting city 39 of set 2|kamenka
# Not found. Next....
# Not found. Next....
# Getting city 40 of set 2|tasiilaq
# Not found. Next....
# Not found. Next....
# Getting city 41 of set 2|nyakabindi
# Not found. Next....
# Getting city 42 of set 2|san patricio
# Not found. Next....
# Getting city 43 of set 2|aklavik
# Not found. Next....
# Getting city 44 of set 2|porto seguro
# Not found. Next....
# Getting city 45 of set 2|hyeres
# Not found. Next....
# Getting city 46 of set 2|camopi
# Not found. Next....
# Getting city 47 of set 2|linjiang
# Not found. Next....
# Getting city 48 of set 2|stavern
# Not found. Next....
# Getting city 49 of set 2|vila franca do campo
# Not found. Next....
# Getting city 50 of set 2|caceres
# Not found. Next....
# Getting city 1 of set 3|esperance
# Not found. Next....
# Getting city 2 of set 3|butaritari
# Not found. Next....
# Getting city 3 of set 3|kizilskoye
# Not found. Next....
# Getting city 4 of set 3|khatanga
# Not found. Next....
# Getting city 5 of set 3|ukiah
# Not found. Next....
# Getting city 6 of set 3|coihaique
# Not found. Next....
# Getting city 7 of set 3|comodoro rivadavia
# Not found. Next....
# Not found. Next....
# Not found. Next....
# Getting city 8 of set 3|victoria
# Not found. Next....
# Getting city 9 of set 3|anchorage
# Not found. Next....
# Getting city 10 of set 3|bustamante
# Not found. Next....
# Getting city 11 of set 3|avarua
# Not found. Next....
# Getting city 12 of set 3|igarka
# Not found. Next....
# Getting city 13 of set 3|sakaiminato
# Not found. Next....
# Getting city 14 of set 3|port alfred
# Not found. Next....
# Not found. Next....
# Getting city 15 of set 3|blythe
# Not found. Next....
# Getting city 16 of set 3|arraial do cabo
# Not found. Next....
# Getting city 17 of set 3|chuy
# Not found. Next....
# Getting city 18 of set 3|katsuura
# Not found. Next....
# Getting city 19 of set 3|turayf
# Not found. Next....
# Getting city 20 of set 3|anadyr
# Not found. Next....
# Getting city 21 of set 3|hithadhoo
# Not found. Next....
# Getting city 22 of set 3|cockburn town
# Not found. Next....
# Getting city 23 of set 3|manono
# Not found. Next....
# Getting city 24 of set 3|moron
# Not found. Next....
# Getting city 25 of set 3|sola
# Not found. Next....
# Getting city 26 of set 3|tuatapere
# Not found. Next....
# Getting city 27 of set 3|alofi
# Not found. Next....
# Getting city 28 of set 3|nanortalik
# Not found. Next....
# Not found. Next....
# Getting city 29 of set 3|sao domingos do maranhao
# Not found. Next....
# Getting city 30 of set 3|narsaq
# Not found. Next....
# Getting city 31 of set 3|shubarkuduk
# Not found. Next....
# Getting city 32 of set 3|la fria
# Not found. Next....
# Getting city 33 of set 3|saskylakh
# Not found. Next....
# Getting city 34 of set 3|severo-kurilsk
# Not found. Next....
# Getting city 35 of set 3|solnechnyy
# Not found. Next....
# Getting city 36 of set 3|kununurra
# Not found. Next....
# Getting city 37 of set 3|melo
# Not found. Next....
# Getting city 38 of set 3|jining
# Not found. Next....
# Getting city 39 of set 3|karratha
# Not found. Next....
# Getting city 40 of set 3|iwaki
# Not found. Next....
# Getting city 41 of set 3|kavieng
# Not found. Next....
# Getting city 42 of set 3|yulara
# Not found. Next....
# Not found. Next....
# Getting city 43 of set 3|portland
# Not found. Next....
# Not found. Next....
# Getting city 44 of set 3|wiang sa
# Not found. Next....
# Getting city 45 of set 3|nieuwpoort
# Not found. Next....
# Not found. Next....
# Getting city 46 of set 3|ararat
# Not found. Next....
# Getting city 47 of set 3|maniitsoq
# Not found. Next....
# Getting city 48 of set 3|leo
# Not found. Next....
# Getting city 49 of set 3|fare
# Not found. Next....
# Getting city 50 of set 3|ust-kuyga
# Not found. Next....
# Getting city 1 of set 4|castro
# Not found. Next....
# Getting city 2 of set 4|sur
# Not found. Next....
# Getting city 3 of set 4|ponta do sol
# Not found. Next....
# Getting city 4 of set 4|atuona
# Not found. Next....
# Not found. Next....
# Getting city 5 of set 4|tessalit
# Not found. Next....
# Getting city 6 of set 4|bambanglipuro
# Not found. Next....
# Getting city 7 of set 4|puerto leguizamo
# Not found. Next....
# Getting city 8 of set 4|college
# Not found. Next....
# Getting city 9 of set 4|baruun-urt
# Not found. Next....
# Getting city 10 of set 4|alice springs
# Not found. Next....
# Getting city 11 of set 4|ariquemes
# Not found. Next....
# Getting city 12 of set 4|eydhafushi
# Not found. Next....
# Getting city 13 of set 4|lugovoy
# Not found. Next....
# Getting city 14 of set 4|te anau
# Not found. Next....
# Getting city 15 of set 4|bar harbor
# Not found. Next....
# Getting city 16 of set 4|carnarvon
# Not found. Next....
# Getting city 17 of set 4|bonthe
# Not found. Next....
# Getting city 18 of set 4|altay
# Not found. Next....
# Getting city 19 of set 4|roura
# Not found. Next....
# Getting city 20 of set 4|avera
# Not found. Next....
# Getting city 21 of set 4|airai
# Not found. Next....
# Getting city 22 of set 4|christchurch
# Not found. Next....
# Not found. Next....
# Not found. Next....
# Getting city 23 of set 4|kulhudhuffushi
# Not found. Next....
# Getting city 24 of set 4|ilhabela
# Not found. Next....
# Getting city 25 of set 4|keetmanshoop
# Not found. Next....
# Getting city 26 of set 4|rio verde de mato grosso
# Not found. Next....
# Getting city 27 of set 4|caravelas
# Not found. Next....
# Getting city 28 of set 4|xining
# Not found. Next....
# Getting city 29 of set 4|bathsheba
# Not found. Next....
# Not found. Next....
# Getting city 30 of set 4|mackay
# Not found. Next....
# Getting city 31 of set 4|candolim
# Not found. Next....
# Getting city 32 of set 4|new norfolk
# Not found. Next....
# Not found. Next....
# Getting city 33 of set 4|necochea
# Not found. Next....
# Getting city 34 of set 4|yatou
# Not found. Next....
# Getting city 35 of set 4|kholtoson
# Not found. Next....
# Getting city 36 of set 4|vestmanna
# Not found. Next....
# Getting city 37 of set 4|boyolangu
# Not found. Next....
# Getting city 38 of set 4|chara
# Not found. Next....
# Getting city 39 of set 4|abu samrah
# Not found. Next....
# Not found. Next....
# Getting city 40 of set 4|alyangula
# Not found. Next....
# Getting city 41 of set 4|kosh-agach
# Not found. Next....
# Getting city 42 of set 4|northam
# Not found. Next....
# Getting city 43 of set 4|palmer
# Not found. Next....
# Getting city 44 of set 4|taltal
# Not found. Next....
# Getting city 45 of set 4|evensk
# Not found. Next....
# Getting city 46 of set 4|cedral
# Not found. Next....
# Getting city 47 of set 4|butajira
# Not found. Next....
# Getting city 48 of set 4|asau
# Not found. Next....
# Getting city 49 of set 4|vestmannaeyjar
# Not found. Next....
# Getting city 50 of set 4|shiyan
# Not found. Next....
# Getting city 1 of set 5|bethel
# Not found. Next....
# Getting city 2 of set 5|faanui
# Not found. Next....
# Getting city 3 of set 5|gao
# Not found. Next....
# Getting city 4 of set 5|suntar
# Not found. Next....
# Getting city 5 of set 5|sarangani
# Not found. Next....
# Getting city 6 of set 5|cabo san lucas
# Not found. Next....
# Getting city 7 of set 5|never
# Not found. Next....
# Getting city 8 of set 5|ribeira grande
# Not found. Next....
# Getting city 9 of set 5|namibe
# Not found. Next....
# Getting city 10 of set 5|dutlwe
# Not found. Next....
# Getting city 11 of set 5|hualmay
# Not found. Next....
# Getting city 12 of set 5|sorland
# Not found. Next....
# Getting city 13 of set 5|sao filipe
# Not found. Next....
# Getting city 14 of set 5|honningsvag
# Not found. Next....
# Getting city 15 of set 5|beloha
# Not found. Next....
# Getting city 16 of set 5|nizwa
# Not found. Next....
# Getting city 17 of set 5|agadir
# Not found. Next....
# Not found. Next....
# Not found. Next....
# Getting city 18 of set 5|jharsuguda
# Not found. Next....
# Getting city 19 of set 5|ngunguru
# Not found. Next....
# Getting city 20 of set 5|suffolk
# Not found. Next....
# Getting city 21 of set 5|sambava
# Not found. Next....
# Getting city 22 of set 5|rawson
# Not found. Next....
# Getting city 23 of set 5|poya
# Not found. Next....
# Getting city 24 of set 5|reporoa
# Not found. Next....
# Getting city 25 of set 5|yellowknife
# Not found. Next....
# Getting city 26 of set 5|cidreira
# Not found. Next....
# Getting city 27 of set 5|bosaso
# Not found. Next....
# Getting city 28 of set 5|arman
# Not found. Next....
# Getting city 29 of set 5|calabozo
# Not found. Next....
# Getting city 30 of set 5|mingyue
# Not found. Next....
# Not found. Next....
# Getting city 31 of set 5|ancud
# Not found. Next....
# Getting city 32 of set 5|iranshahr
# Not found. Next....
# Getting city 33 of set 5|dikson
# Not found. Next....
# Getting city 34 of set 5|touros
# Not found. Next....
# Getting city 35 of set 5|cayenne
# Not found. Next....
# Getting city 36 of set 5|riachao das neves
# Not found. Next....
# Getting city 37 of set 5|takaka
# Not found. Next....
# Getting city 38 of set 5|nisia floresta
# Not found. Next....
# Getting city 39 of set 5|tilichiki
# Not found. Next....
# Getting city 40 of set 5|quesnel
# Not found. Next....
# Getting city 41 of set 5|sompeta
# Not found. Next....
# Getting city 42 of set 5|amazar
# Not found. Next....
# Getting city 43 of set 5|burnie
# Not found. Next....
# Getting city 44 of set 5|cabedelo
# Not found. Next....
# Getting city 45 of set 5|barra do garcas
# Not found. Next....
# Getting city 46 of set 5|westport
# Not found. Next....
# Getting city 47 of set 5|clarence town
# Not found. Next....
# Getting city 48 of set 5|bouza
# Not found. Next....
# Getting city 49 of set 5|reconquista
# Not found. Next....
# Getting city 50 of set 5|peniche
# Not found. Next....
# Getting city 1 of set 6|half moon bay
# Not found. Next....
# Getting city 2 of set 6|micheweni
# Not found. Next....
# Getting city 3 of set 6|mancio lima
# Not found. Next....
# Not found. Next....
# Getting city 4 of set 6|lucea
# Not found. Next....
# Getting city 5 of set 6|lasa
# Not found. Next....
# Getting city 6 of set 6|bilma
# Not found. Next....
# Getting city 7 of set 6|matara
# Not found. Next....
# Getting city 8 of set 6|champaign
# Not found. Next....
# Getting city 9 of set 6|riberalta
# Not found. Next....
# Getting city 10 of set 6|rincon
# Not found. Next....
# Getting city 11 of set 6|jati
# Not found. Next....
# Getting city 12 of set 6|vao
# Not found. Next....
# Getting city 13 of set 6|pasighat
# Not found. Next....
# Getting city 14 of set 6|ciudad del maiz
# Not found. Next....
# Getting city 15 of set 6|san policarpo
# Not found. Next....
# Getting city 16 of set 6|thinadhoo
# Not found. Next....
# Getting city 17 of set 6|port hardy
# Not found. Next....
# Getting city 18 of set 6|fortuna
# Not found. Next....
# Getting city 19 of set 6|okhotsk
# Not found. Next....
# Getting city 20 of set 6|marang
# Not found. Next....
# Getting city 21 of set 6|ilulissat
# Not found. Next....
# Getting city 22 of set 6|provideniya
# Not found. Next....
# Getting city 23 of set 6|san cristobal
# Not found. Next....
# Getting city 24 of set 6|tatawin
# Not found. Next....
# Getting city 25 of set 6|muros
# Not found. Next....
# Getting city 26 of set 6|batemans bay
# Not found. Next....
# Getting city 27 of set 6|alta floresta
# Not found. Next....
# Getting city 28 of set 6|viedma
# Not found. Next....
# Getting city 29 of set 6|pecos
# Not found. Next....
# Getting city 30 of set 6|zhigansk
# Not found. Next....
# Getting city 31 of set 6|boa esperanca
# Not found. Next....
# Getting city 32 of set 6|moose factory
# Not found. Next....
# Getting city 33 of set 6|mount isa
# Not found. Next....
# Getting city 34 of set 6|tateyama
# Not found. Next....
# Not found. Next....
# Getting city 35 of set 6|ixtapa
# Not found. Next....
# Getting city 36 of set 6|adrar
# Not found. Next....
# Getting city 37 of set 6|uchiza
# Not found. Next....
# Getting city 38 of set 6|brookhaven
# Not found. Next....
# Getting city 39 of set 6|nome
# Not found. Next....
# Getting city 40 of set 6|eberswalde
# Not found. Next....
# Getting city 41 of set 6|sheridan
# Not found. Next....
# Getting city 42 of set 6|rio gallegos
# Not found. Next....
# Getting city 43 of set 6|iqaluit
# Not found. Next....
# Getting city 44 of set 6|rocha
# Not found. Next....
# Getting city 45 of set 6|kingsville
# Not found. Next....
# Getting city 46 of set 6|tabou
# Not found. Next....
# Getting city 47 of set 6|bereda
# Not found. Next....
# Getting city 48 of set 6|palora
# Not found. Next....
# Getting city 49 of set 6|kupang
# Not found. Next....
# Getting city 50 of set 6|tocopilla
# Not found. Next....
# Getting city 1 of set 7|lindas
# Not found. Next....
# Getting city 2 of set 7|san fernando
# Not found. Next....
# Getting city 3 of set 7|buala
# Not found. Next....
# Not found. Next....
# Getting city 4 of set 7|beyneu
# Not found. Next....
# Getting city 5 of set 7|ahipara
# Not found. Next....
# Getting city 6 of set 7|puksoozero
# Not found. Next....
# Getting city 7 of set 7|zhangye
# Not found. Next....
# Getting city 8 of set 7|birjand
# Not found. Next....
# Getting city 9 of set 7|costinesti
# Not found. Next....
# Getting city 10 of set 7|saint-michel-des-saints
# Not found. Next....
# Not found. Next....
# Getting city 11 of set 7|kovur
# Not found. Next....
# Getting city 12 of set 7|pevek
# Not found. Next....
# Getting city 13 of set 7|wolbrom
# Not found. Next....
# Not found. Next....
# Getting city 14 of set 7|mareeba
# Not found. Next....
# Not found. Next....
# Getting city 15 of set 7|marienburg
# Not found. Next....
# Getting city 16 of set 7|balikpapan
# Not found. Next....
# Getting city 17 of set 7|lavrentiya
# Not found. Next....
# Getting city 18 of set 7|sao joao da barra
# Not found. Next....
# Getting city 19 of set 7|huancabamba
# Not found. Next....
# Getting city 20 of set 7|souillac
# Not found. Next....
# Getting city 21 of set 7|kudahuvadhoo
# Not found. Next....
# Getting city 22 of set 7|kahului
# Not found. Next....
# Getting city 23 of set 7|beinamar
# Not found. Next....
# Getting city 24 of set 7|narsipatnam
# Not found. Next....
# Getting city 25 of set 7|chapais
# Not found. Next....
# Getting city 26 of set 7|shimanovsk
# Not found. Next....
# Getting city 27 of set 7|thames
# Not found. Next....
# Getting city 28 of set 7|awash
# Not found. Next....
# Not found. Next....
# Getting city 29 of set 7|rena
# Not found. Next....
# Getting city 30 of set 7|saint-joseph
# Not found. Next....
# Getting city 31 of set 7|teya
# Not found. Next....
# Getting city 32 of set 7|aitape
# Not found. Next....
# Getting city 33 of set 7|tahe
# Not found. Next....
# Getting city 34 of set 7|bitung
# Not found. Next....
# Getting city 35 of set 7|kodiak
# Not found. Next....
# Getting city 36 of set 7|pelham
# Not found. Next....
# Getting city 37 of set 7|hay river
# Not found. Next....
# Getting city 38 of set 7|serdobsk
# Not found. Next....
# Getting city 39 of set 7|sterling
# Not found. Next....
# Getting city 40 of set 7|pacific grove
# Not found. Next....
# Getting city 41 of set 7|port-cartier
# Not found. Next....
# Not found. Next....
# Getting city 42 of set 7|cuamba
# Not found. Next....
# Getting city 43 of set 7|disna
# Not found. Next....
# Getting city 44 of set 7|luang prabang
# Not found. Next....
# Getting city 45 of set 7|inuvik
# Not found. Next....
# Getting city 46 of set 7|junction city
# Not found. Next....
# Getting city 47 of set 7|olhao
# Not found. Next....
# Getting city 48 of set 7|madimba
# Not found. Next....
# Getting city 49 of set 7|omsukchan
# Not found. Next....
# Getting city 50 of set 7|panshi
# Not found. Next....
# Getting city 1 of set 8|santo andre
# Not found. Next....
# Getting city 2 of set 8|salalah
# Not found. Next....
# Not found. Next....
# Getting city 3 of set 8|kenora
# Not found. Next....
# Getting city 4 of set 8|saint anthony
# Not found. Next....
# Getting city 5 of set 8|livingstonia
# Not found. Next....
# Not found. Next....
# Not found. Next....
# Getting city 6 of set 8|mahebourg
# Not found. Next....
# Getting city 7 of set 8|formosa
# Not found. Next....
# Not found. Next....
# Getting city 8 of set 8|taoudenni
# Not found. Next....
# Getting city 9 of set 8|gat
# Not found. Next....
# Getting city 10 of set 8|baykit
# Not found. Next....
# Getting city 11 of set 8|helong
# Not found. Next....
# Getting city 12 of set 8|lompoc
# Not found. Next....
# Getting city 13 of set 8|raga
# Not found. Next....
# Not found. Next....
# Getting city 14 of set 8|tuban
# Not found. Next....
# Getting city 15 of set 8|angoram
# Not found. Next....
# Getting city 16 of set 8|acapulco
# Not found. Next....
# Getting city 17 of set 8|makubetsu
# Not found. Next....
# Getting city 18 of set 8|mahibadhoo
# Not found. Next....
# Getting city 19 of set 8|orotukan
# Not found. Next....
# Getting city 20 of set 8|coahuayana
# Not found. Next....
# Not found. Next....
# Getting city 21 of set 8|ureki
# Not found. Next....
# Getting city 22 of set 8|namatanai
# Not found. Next....
# Getting city 23 of set 8|lodwar
# Not found. Next....
# Getting city 24 of set 8|baghdad
# Not found. Next....
# Getting city 25 of set 8|vila
# Not found. Next....
# Getting city 26 of set 8|sioux lookout
# Not found. Next....
# Getting city 27 of set 8|kaeo
# Not found. Next....
# Getting city 28 of set 8|mnogovershinnyy
# Not found. Next....
# Getting city 29 of set 8|lakselv
# Not found. Next....
# Getting city 30 of set 8|iskateley
# Not found. Next....
# Getting city 31 of set 8|soubre
# Not found. Next....
# Getting city 32 of set 8|greensburg
# Not found. Next....
# Getting city 33 of set 8|bandarbeyla
# Not found. Next....
# Getting city 34 of set 8|bogande
# Not found. Next....
# Getting city 35 of set 8|geraldton
# Not found. Next....
# Getting city 36 of set 8|rafai
# Not found. Next....
# Not found. Next....
# Getting city 37 of set 8|nemuro
# Not found. Next....
# Getting city 38 of set 8|agapovka
# Not found. Next....
# Getting city 39 of set 8|zhongshu
# Not found. Next....
# Getting city 40 of set 8|usinsk
# Not found. Next....
# Getting city 41 of set 8|arlit
# Not found. Next....
# Not found. Next....
# Getting city 42 of set 8|lata
# Not found. Next....
# Getting city 43 of set 8|ust-barguzin
# Not found. Next....
# Getting city 44 of set 8|donskoy
# Not found. Next....
# Getting city 45 of set 8|nishihara
# Not found. Next....
# Not found. Next....
# Getting city 46 of set 8|sainte-anne-des-monts
# Not found. Next....
# Getting city 47 of set 8|sabha
# Not found. Next....
# Getting city 48 of set 8|hokitika
# Not found. Next....
# Getting city 49 of set 8|cesenatico
# Not found. Next....
# Getting city 50 of set 8|bay roberts
# Not found. Next....
# Getting city 1 of set 9|kachug
# Not found. Next....
# Getting city 2 of set 9|saint george
# Not found. Next....
# Getting city 3 of set 9|taksimo
# Not found. Next....
# Getting city 4 of set 9|gomel
# Not found. Next....
# Getting city 5 of set 9|wanparti
# Not found. Next....
# Getting city 6 of set 9|porto recanati
# Not found. Next....
# Getting city 7 of set 9|dingle
# Not found. Next....
# Getting city 8 of set 9|kodinsk
# Not found. Next....
# Getting city 9 of set 9|neiafu
# Not found. Next....
# Getting city 10 of set 9|poum
# Not found. Next....
# Getting city 11 of set 9|hobyo
# Not found. Next....
# Getting city 12 of set 9|santa cruz
# Not found. Next....
# Getting city 13 of set 9|waingapu
# Not found. Next....
# Getting city 14 of set 9|taft
# Not found. Next....
# Getting city 15 of set 9|blind river
# Not found. Next....
# Getting city 16 of set 9|saldanha
# Not found. Next....
# Getting city 17 of set 9|lisburn
# Not found. Next....
# Getting city 18 of set 9|ahmadnagar
# Not found. Next....
# Getting city 19 of set 9|luderitz
# Not found. Next....
# Not found. Next....
# Getting city 20 of set 9|xichang
# Not found. Next....
# Not found. Next....
# Getting city 21 of set 9|flinders
# Not found. Next....
# Getting city 22 of set 9|sao borja
# Not found. Next....
# Not found. Next....
# Getting city 23 of set 9|leningradskiy
# Not found. Next....
# Getting city 24 of set 9|oistins
# Not found. Next....
# Getting city 25 of set 9|prokopyevsk
# Not found. Next....
# Getting city 26 of set 9|la ronge
# Not found. Next....
# Getting city 27 of set 9|batticaloa
# Not found. Next....
# Getting city 28 of set 9|olafsvik
# Not found. Next....
# Getting city 29 of set 9|campina grande do sul
# Not found. Next....
# Getting city 30 of set 9|mehran
# Not found. Next....
# Getting city 31 of set 9|majene
# Not found. Next....
# Getting city 32 of set 9|jalu
# Not found. Next....
# Getting city 33 of set 9|imuris
# Not found. Next....
# Getting city 34 of set 9|makakilo city
# Not found. Next....
# Getting city 35 of set 9|cumpas
# Not found. Next....
# Getting city 36 of set 9|innisfail
# Not found. Next....
# Getting city 37 of set 9|nchelenge
# Not found. Next....
# Getting city 38 of set 9|laje
# Not found. Next....
# Getting city 39 of set 9|vanavara
# Not found. Next....
# Getting city 40 of set 9|kruisfontein
# Not found. Next....
# Getting city 41 of set 9|antropovo
# Not found. Next....
# Getting city 42 of set 9|katangli
# Not found. Next....
# Not found. Next....
# Getting city 43 of set 9|padre bernardo
# Not found. Next....
# Getting city 44 of set 9|porto torres
# Not found. Next....
# Not found. Next....
# Getting city 45 of set 9|aswan
# Not found. Next....
# Not found. Next....
# Getting city 46 of set 9|san vicente
# Not found. Next....
# Getting city 47 of set 9|shitkino
# Not found. Next....
# Getting city 48 of set 9|nikolsk
# Not found. Next....
# Getting city 49 of set 9|falmouth
# Not found. Next....
# Getting city 50 of set 9|pokhara
# Not found. Next....
# Getting city 1 of set 10|cap-aux-meules
# Not found. Next....
# Getting city 2 of set 10|tura
# Not found. Next....
# Getting city 3 of set 10|sosnovoborsk
# Not found. Next....
# Getting city 4 of set 10|mukhen
# Not found. Next....
# Getting city 5 of set 10|acarau
# Not found. Next....
# Getting city 6 of set 10|honiara
# Not found. Next....
# Getting city 7 of set 10|norway
# Not found. Next....
# Getting city 8 of set 10|griffith
# Not found. Next....
# Getting city 9 of set 10|astana
# Not found. Next....
# Getting city 10 of set 10|chalmette
# Not found. Next....
# Getting city 11 of set 10|korbach
# Not found. Next....
# Getting city 12 of set 10|lachi
# Not found. Next....
# Getting city 13 of set 10|donskoye
# Not found. Next....
# Getting city 14 of set 10|sanmenxia
# Not found. Next....
# Getting city 15 of set 10|petropavlovsk-kamchatskiy
# Not found. Next....
# Getting city 16 of set 10|port hawkesbury
# Not found. Next....
# Getting city 17 of set 10|gubkinskiy
# Not found. Next....
# Getting city 18 of set 10|redlands
# Not found. Next....
# Not found. Next....
# Getting city 19 of set 10|los llanos de aridane
# Not found. Next....
# Getting city 20 of set 10|tarauaca
# Not found. Next....
# Getting city 21 of set 10|argostolion
# Not found. Next....
# Getting city 22 of set 10|aguimes
# Not found. Next....
# Getting city 23 of set 10|masvingo
# Not found. Next....
# Not found. Next....
# Getting city 24 of set 10|trelew
# Not found. Next....
# Getting city 25 of set 10|port lincoln
# Not found. Next....
# Getting city 26 of set 10|havre-saint-pierre
# Not found. Next....
# Getting city 27 of set 10|korla
# Not found. Next....
# Getting city 28 of set 10|pinczow
# Not found. Next....
# Getting city 29 of set 10|eyl
# Not found. Next....
# Getting city 30 of set 10|channel-port aux basques
# Not found. Next....
# Getting city 31 of set 10|plettenberg bay
# Not found. Next....
# Getting city 32 of set 10|winterberg
# Not found. Next....
# Getting city 33 of set 10|raiganj
# Not found. Next....
# Getting city 34 of set 10|dabhol
# Not found. Next....
# Getting city 35 of set 10|bilibino
# Not found. Next....
# Getting city 36 of set 10|xiangxiang
# Not found. Next....
# Getting city 37 of set 10|anloga
# Not found. Next....
# Getting city 38 of set 10|amahai
# Not found. Next....
# Getting city 39 of set 10|mogeiro
# Not found. Next....
# Getting city 40 of set 10|kokopo
# Not found. Next....
# Getting city 41 of set 10|odweyne
# Not found. Next....
# Getting city 42 of set 10|aripuana
# Not found. Next....
# Getting city 43 of set 10|chingirlau
# Not found. Next....
# Getting city 44 of set 10|mingguang
# Not found. Next....
# Getting city 45 of set 10|penapolis
# Not found. Next....
# Not found. Next....
# Getting city 46 of set 10|mastung
# Not found. Next....
# Getting city 47 of set 10|verkhnevilyuysk
# Not found. Next....
# Getting city 48 of set 10|ronne
# Not found. Next....
# Getting city 49 of set 10|longview
# Not found. Next....
# Getting city 50 of set 10|mezen
# Not found. Next....
# Getting city 1 of set 11|marieville
# Not found. Next....
# Getting city 2 of set 11|antofagasta
# Not found. Next....
# Getting city 3 of set 11|joshimath
# Not found. Next....
# Not found. Next....
# Getting city 4 of set 11|whitehorse
# Not found. Next....
# Getting city 5 of set 11|nhulunbuy
# Not found. Next....
# Getting city 6 of set 11|tangzhai
# Not found. Next....
# Getting city 7 of set 11|sinnamary
# Not found. Next....
# Getting city 8 of set 11|tucuman
# Not found. Next....
# Getting city 9 of set 11|el naranjo
# Not found. Next....
# Getting city 10 of set 11|pingliang
# Not found. Next....
# Getting city 11 of set 11|dinghai
# Not found. Next....
# Getting city 12 of set 11|guerrero negro
# Not found. Next....
# Getting city 13 of set 11|pereslavl-zalesskiy
# Not found. Next....
# Getting city 14 of set 11|itarema
# Not found. Next....
# Getting city 15 of set 11|toora-khem
# Not found. Next....
# Getting city 16 of set 11|oyonnax
# Not found. Next....
# Getting city 17 of set 11|kisangani
# Not found. Next....
# Not found. Next....
# Getting city 18 of set 11|russellville
# Not found. Next....
# Getting city 19 of set 11|den helder
# Not found. Next....
# Getting city 20 of set 11|daru
# Not found. Next....
# Getting city 21 of set 11|goderich
# Not found. Next....
# Getting city 22 of set 11|fort saint james
# Not found. Next....
# Getting city 23 of set 11|bischofswerda
# Not found. Next....
# Getting city 24 of set 11|shibetsu
# Not found. Next....
# Getting city 25 of set 11|umm lajj
# Not found. Next....
# Getting city 26 of set 11|hohhot
# Not found. Next....
# Getting city 27 of set 11|vyazemskiy
# Not found. Next....
# Getting city 28 of set 11|ivanovskoye
# Not found. Next....
# Getting city 29 of set 11|were ilu
# Not found. Next....
# Not found. Next....
# Getting city 30 of set 11|yellandu
# Not found. Next....
# Getting city 31 of set 11|poso
# Not found. Next....
# Not found. Next....
# Getting city 32 of set 11|vostok
# Not found. Next....
# Getting city 33 of set 11|sao desiderio
# Not found. Next....
# Getting city 34 of set 11|ramos arizpe
# Not found. Next....
# Not found. Next....
# Getting city 35 of set 11|dobarceni
# Not found. Next....
# Getting city 36 of set 11|antonina
# Not found. Next....
# Getting city 37 of set 11|alappuzha
# Not found. Next....
# Getting city 38 of set 11|saint-francois
# Not found. Next....
# Getting city 39 of set 11|nikki
# Not found. Next....
# Getting city 40 of set 11|verkh-usugli
# Not found. Next....
# Not found. Next....
# Getting city 41 of set 11|brae
# Not found. Next....
# Getting city 42 of set 11|luwuk
# Not found. Next....
# Not found. Next....
# Not found. Next....
# Getting city 43 of set 11|bulgan
# Not found. Next....
# Getting city 44 of set 11|pemangkat
# Not found. Next....
# Getting city 45 of set 11|liberty
# Not found. Next....
# Getting city 46 of set 11|clyde river
# Not found. Next....
# Getting city 47 of set 11|waipawa
# Not found. Next....
# Getting city 48 of set 11|tibati
# Not found. Next....
# Getting city 49 of set 11|tongzi
# Not found. Next....
# Getting city 50 of set 11|maningrida
# Not found. Next....
# Getting city 1 of set 12|qasigiannguit
# Not found. Next....
# -----------------------------
# Complete!
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Dataframe creation
weather_frame = pd.DataFrame({
    'City': city,
    'Cloudiness': cloud,
    'Country': country,
    'Date': date,
    'Humidity': humid,
    'Latitude': lat,
    'Longitude': long,
    'Max Temp': temp_max,
    'Windspeed': wind
    
})

# %%
weather_frame.to_csv("Output/weather_data.csv")

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
weather_frame.describe()
# Out:
#        Cloudiness          Date    Humidity    Latitude   Longitude  \
# count  551.000000  5.510000e+02  551.000000  551.000000  551.000000
# mean    45.341198  1.604805e+09   73.061706   20.597985   20.429074
# std     39.614732  9.715794e+01   19.064384   33.528004   92.323663
# min      0.000000  1.604805e+09    7.000000  -54.800000 -175.200000
# 25%      1.000000  1.604805e+09   63.000000   -8.150000  -60.140000
# 50%     40.000000  1.604805e+09   77.000000   27.730000   24.970000
# 75%     88.500000  1.604805e+09   87.000000   48.965000  103.650000
# max    100.000000  1.604805e+09  100.000000   77.480000  179.320000
#
#          Max Temp   Windspeed
# count  551.000000  551.000000
# mean    13.919183    3.592976
# std     12.539537    2.593938
# min    -29.340000    0.040000
# 25%      6.000000    1.725000
# 50%     16.110000    3.100000
# 75%     23.650000    5.045000
# max     36.000000   25.700000

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(weather_frame['Latitude'], weather_frame['Max Temp'], marker="d", facecolors="yellow", edgecolors="pink")

# Format graph
plt.title ("Latitude vs Max Temperature")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (C)")
plt.grid()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(weather_frame['Latitude'], weather_frame['Humidity'], marker="d", facecolors="blue", edgecolors="pink")

# Format graph
plt.title ("Latitude vs Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity %")
plt.grid()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_frame['Latitude'], weather_frame['Cloudiness'], marker="d", facecolors="silver", edgecolors="black")

# Format graph
plt.title ("Latitude vs Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness %")
plt.grid()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_frame['Latitude'], weather_frame['Windspeed'], marker="d", facecolors="purple", edgecolors="white")

# Format graph
plt.title ("Latitude vs Windspeed")
plt.xlabel("Latitude")
plt.ylabel("Windspeed (km/h)")
plt.grid()

# %% [markdown]
# ## Linear Regression

# %%
#create dataphrames for n and s hemispheres
n_hemisphere = weather_frame[(weather_data["Latitude"] >= 0)]
s_hemisphere = weather_frame[(weather_data["Latitude"] < 0)]
n_hemisphere
s_hemisphere
# Out:
#               City  Cloudiness Country        Date  Humidity  Latitude  \
# 0    qasigiannguit         100      PF  1604805134        74    -23.12
# 2    qasigiannguit          20      TO  1604804935        74    -21.20
# 11   qasigiannguit          75      ZA  1604805074        93    -33.93
# 12   qasigiannguit           0      CL  1604805057        69    -35.33
# 13   qasigiannguit          27      VU  1604805196        75    -19.55
# ..             ...         ...     ...         ...       ...       ...
# 532  qasigiannguit          48      BR  1604805258        88    -12.36
# 535  qasigiannguit          90      BR  1604805258       100    -25.43
# 541  qasigiannguit         100      ID  1604805259        50     -0.95
# 546  qasigiannguit         100      NZ  1604805260        81    -41.41
# 549  qasigiannguit          61      AU  1604805260        52    -12.07
#
#      Longitude  Max Temp  Windspeed
# 0      -134.97     22.08       7.98
# 2      -175.20     27.00       4.10
# 11       18.42     15.00       6.70
# 12      -72.42     14.54       3.87
# 13      169.27     27.01       3.91
# ..         ...       ...        ...
# 532     -44.97     21.20       1.34
# 535     -48.71     14.00       3.10
# 541     122.79     30.56       3.82
# 546     175.52     11.00      16.50
# 549     134.27     33.27       6.14
#
# [170 rows x 9 columns]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#create linear regression formula to apply later

def line_reg(x,y):
   
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    print(f"Correlation : {round(rvalue,2)}")
    best_plots = x * slope + intercept
    best_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x, y, marker="d", facecolors="yellow", edgecolors="black")
    plt.plot(x,best_plots,linewidth = .99,color="purple")
    return best_equation

# create function to annotate
def annotate(best_equation, a, b):
    plt.annotate(best_equation,(a,b),fontsize=12)
    
    
    
# x and y values
xy = line_reg(n_hemisphere['Latitude'], n_hemisphere['Max Temp'])

# add regression formula
plt.annotate(xy,(-20,20),color="black")

# Formatting 
plt.title ("N. Hemisphere - Max Temperature (C) vs Latitude")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.grid()

# Save plot
plt.savefig("Output/Northern_Hemisphere_MaxTemp")
# Out:
# Correlation : -0.87

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# x and y values
xy = line_reg(s_hemisphere['Latitude'], s_hemisphere['Max Temp'])

# add regression formula
plt.annotate(xy,(0,20),color="black")

# Formatting 
plt.title ("S. Hemisphere - Max Temperature (C) vs Latitude")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.grid()

# Save scatter plot as png file to output folder
plt.savefig("Output/S_Hemisphere_MaxTemp")
# Out:
# Correlation : 0.71

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# x and y values
xy = line_reg(s_hemisphere['Latitude'], s_hemisphere['Humidity'])

# add regression formula
plt.annotate(xy,(0,20),color="black")

# Formatting 
plt.title ("N. Hemisphere - Humidity (C) vs Latitude")
plt.xlabel("Latitude")
plt.ylabel("Humdity %")
plt.grid()

# Save scatter plot as png file to output folder
plt.savefig("Output/N_Hemisphere_Humidity")
# Out:
# Correlation : 0.11

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# x and y values
xy = line_reg(s_hemisphere['Latitude'], s_hemisphere['Humidity'])

# add regression formula
plt.annotate(xy,(0,20),color="black")

# Formatting 
plt.title ("N. Hemisphere - Humidity (C) vs Latitude")
plt.xlabel("Latitude")
plt.ylabel("Humdity %")
plt.grid()

# Save 
plt.savefig("Output/S_Hemisphere_Humidity")
# Out:
# Correlation : 0.11

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# x and y values
xy = line_reg(n_hemisphere['Latitude'], n_hemisphere['Cloudiness'])

# add regression formula
plt.annotate(xy,(0,20),color="black")

# Formatting 
plt.title ("N. Hemisphere - Cloudiness vs Latitude")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness%")
plt.grid()

# Save 
plt.savefig("Output/N_Hemisphere_Cloudiness")
# Out:
# Correlation : 0.23

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# x and y values
xy = line_reg(s_hemisphere['Latitude'], s_hemisphere['Cloudiness'])

# add regression formula
plt.annotate(xy,(0,20),color="black")

# Formatting 
plt.title ("S. Hemisphere - Cloudiness vs Latitude")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness%")
plt.grid()

# Save 
plt.savefig("Output/S_Hemisphere_Cloudiness")
# Out:
# Correlation : 0.24

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# x and y values
xy = line_reg(n_hemisphere['Latitude'], n_hemisphere['Windspeed'])

# add regression formula
plt.annotate(xy,(0,20),color="black")

# Formatting 
plt.title ("N. Hemisphere - Wind Speed vs Latitude")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (km/h)")
plt.grid()

# Save 
plt.savefig("Output/N_Hemisphere_Windspeed")
# Out:
# Correlation : 0.15

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# x and y values
xy = line_reg(s_hemisphere['Latitude'], s_hemisphere['Windspeed'])

# add regression formula
plt.annotate(xy,(0,20),color="black")

# Formatting 
plt.title ("S. Hemisphere - Wind Speed vs Latitude")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (Km/h)")
plt.grid()

# Save 
plt.savefig("Output/S_Hemisphere_Windspeed")
# Out:
# Correlation : -0.3
